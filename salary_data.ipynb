# %% [markdown]
# <a href="https://colab.research.google.com/github/GRVinay/My-Learning/blob/main/salary_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# step 1 import library
import pandas as pd

# %%
# step 2 import data
salary = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
# step 3 define target (y) and features (x)
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y = salary['Salary']
x = salary[['Experience Years']]

# %%
# step  4 splitting the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2529)

# %%
# step 5 select model
from sklearn.linear_model import  LinearRegression
model = LinearRegression()

# %%
# step 6 train model (fit model)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 27010.963630394683

# %%
model.coef_
# Out:
# array([9343.3671387])

# %%
# step 7 prediction
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 90545.86017355,  59712.74861584, 106429.58430934,  64384.43218519,
#         69056.11575454, 123247.645159  ,  84939.83989033,  63450.09547132,
#         65318.76889906,  61581.42204358])

# %%
x_test
# Out:
#     Experience Years
# 29               6.8
# 11               3.5
# 33               8.5
# 16               4.0
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9
# 17               4.1
# 12               3.7

# %%
# step 8 accuracy
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4182.144652363717

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.06230870755908321

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 27140319.661844987
